# %%
exp=-1
total=0
maxep=0
while (exp!=0):
    exp=int(input("enter the expenses (type 0 to stop) : "))
    total= total+exp
    if (exp>maxep): 
         maxep=exp
    print ("your total expenses is " +str(total))
    print("your maximum amount is " +str(maxep))
# Out:
# enter the expenses (type 0 to stop) :  20
# your total expenses is 20
# your maximum amount is 20
# enter the expenses (type 0 to stop) :  30
# your total expenses is 50
# your maximum amount is 30
# enter the expenses (type 0 to stop) :  40
# your total expenses is 90
# your maximum amount is 40
# enter the expenses (type 0 to stop) :  50
# your total expenses is 140
# your maximum amount is 50
# enter the expenses (type 0 to stop) :  0
# your total expenses is 140
# your maximum amount is 50
